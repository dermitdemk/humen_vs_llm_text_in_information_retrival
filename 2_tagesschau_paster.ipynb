# %%
import json
import pandas as pd
import numpy as np

# %%
## creating a parser class
class tagesschau_article:
    def __init__(self,path):
        """Automatically get all the important information of the article out of the JSON.

        Args:
            path (str): path to the json file
        """
        self.json_data = self.read_json(path)
        self.content = self.get_content()
        self.tags = self.get_tags()
        self.title = self.get_title()
        self.resort = self.get_ressort()
        self.type = self.get_type()
        self.content_as_list = self.get_content(True)
        
        
    def read_json(self,path):
        ## reads the json file
        with open (path,'r') as file:
            data =json.load(file)
            return data
    
    def get_content(self, as_list=False):
        """Extracts the content out of the file. You can either extract it as a list, then each block is an entry of the list, or as one big str

        Args:
            as_list (bool, optional): if you want the content in blocks or all as one str. Defaults to False.

        Returns:
            str: the content
        """
        data = self.json_data
        text = []
        for i in data['content']:
            if i['type'] =='text':
                text.append(i['value'])
        if as_list == True:
            return(text)                
        return '\n'.join(text)
    
    #def get_content_as_list(self):
        
    
    def get_tags(self):
        """Returns the tags of the article

        Returns:
            str: The tags
        """
        data = self.json_data
        tags = []
        #if 'tag' not in data.keys():
        #    return np.nan
        for i in data['tags']:
            tags.append(i['tag'])
        return tags
    def get_title(self):
        """Returns the title

        Returns:
            _type_: _description_
        """
        data = self.json_data
        if 'title' not in data.keys():
            return np.nan
        return data['title']

    def get_type(self):
        """Returns the type

        Returns:
            _type_: _description_
        """
        data = self.json_data
        if 'type' not in data.keys():
            return np.nan
        return data['type']

    def get_ressort(self):
        """Returns the ressort

        Returns:
            str: _description_
        """
        data = self.json_data
        if 'ressort' not in data.keys():
            return np.nan
        return data['ressort']
    
    
    def to_dict(self, with_singel_tags=True):
        """Converts all the attributs of the class to a dict. This can be used to make a pd.df out of it

        Args:
            with_singel_tags (bool, optional): Then the list of tags is converted also in elements of the dicts. Defaults to True.

        Returns:
            dict: _description_
        """
        id = [f'tag_{i}' for i in range(len(self.tags))]
        tag_dict = {i:t for i,t in zip(id,self.tags)}
        data_dict = {'title':self.title,'content':self.content,'content_as_list':self.content_as_list,'tags':self.tags,'ressort':self.resort,'type':self.type}
        if with_singel_tags:
            data_dict.update(tag_dict)
        return data_dict

# %%
## Example for single article
tagesschau_article('data/-ausland-afrika-cholera-simbabwe-100.json').to_dict()
# Out:
# {'title': 'Cholera breitet sich in Simbabwe aus',
#  'content': '<strong>Simbabwe kämpft gegen einen Cholera-Ausbruch. Seit Februar sind bereits mehr als 200 Menschen an der hochansteckenden Durchfallerkrankung gestorben, Tausende haben sich infiziert. Experten vermuten noch höhere Zahlen.</strong>\n<em>Von Karin Wehrheim, ARD Johannesburg</em>\nIn Kuwadzana, einem Vorort von Harare, fließt das Abwasser zwischen den Hütten hindurch. Es ist mit Cholera-Bakterien verseuchtes Wasser aus aufgeplatzten Abwasserrohren. Berge von Müll türmen sich an den Straßen. Das gehe schon seit Monaten so, sagt Lucia Rupende und zeigt auf Maden in den Pfützen. Ihre Kinder lässt sie deshalb nicht hinaus.\n"Das ist schrecklich. Sind wir Tiere?", fragt sie. "Es ist unerträglich, wie wir leben." Die Kinder müssten drinnen bleiben und könnten nicht draußen spielen. "Wir haben Angst, dass sie sich mit Cholera anstecken", sagt sie.\n40 Prozent der Cholera-Fälle in der Hauptstadt werden derzeit aus dem Vorort Kuwadzana gemeldet. Dort leben Menschen mit wenig Geld. Stephen Masvingo hält sich mit einem Barbershop über Wasser. Sein Salon aus Blech und Brettern hat keinen Wasseranschluss. \nEr ist froh, Cholera überlebt zu haben. Drei Tage habe er Durchfall gehabt, musste sich übergeben, erzählt er. "Ich dachte, das vergeht. Aber ich konnte nichts bei mir behalten." Er habe sich sehr schwach gefühlt. "Dann hat meine Frau Hilfe geholt, ich kam sofort ins Krankenhaus."\nStephen Masvingo geht davon aus, dass er sich bei einem Kunden angesteckt hat. Manchmal vergesse man einfach, sich die Hände zu waschen - und esse<strong> </strong>dann was oder kaue Nägel.\nIn Simbabwe wie auch in den Nachbarländern Mosambik und Südafrika gibt es immer wieder Cholera-Epidemien, weil die Wasser- und Abwasserleitungen marode sind. Regina Feindt arbeitet für die Welthungerhilfe in Harare. Sie berichtet, nicht jeder Haushalt habe eine eigene Toilette. "Und Gemeinschaftstoiletten sind in einem teils schlechten Zustand. Das heißt, die Menschen gehen auch teilweise einfach hinters Haus."\nDer nächste Regen nimmt es mit. So gelangt das stinkende Abwasser, das Lucias Rupendes Hütte umgibt, über einen Bach schließlich in den Chivero-Stausee, Harares wichtigsten Trinkwasserspeicher. \nDie Durchfallkrankheit finde im südlichen Afrika besonders leicht Opfer. In Simbabwe sei die Ernährungssituation ohnehin sehr angespannt, ungefähr 30 Prozent der Bevölkerung seien schlecht ernährt. In solchen Ländern sei "eine solche Erkrankung ein Riesenproblem, die den Hunger letztendlich noch einmal verschärft".\nBisher geht die Regierung von 9.400 Cholera-Fällen in Simbabwe aus. Doch das ist vermutlich nur die Spitze des Eisbergs. Viele gehen nicht zum Arzt, manche haben auch keine Symptome, geben die Krankheit aber trotzdem weiter.\nSchon Mitte November hatte der Chef der städtischen Gesundheitsbehörde erklärt, die Lage in Harare gerate außer Kontrolle. Regierung und Hilfsorganisationen verteilten Chlortabletten, Seife und sauberes Wasser aus Tankwagen. Aber wenn jetzt die Regenzeit beginnt, könnte die Lage so schlimm werden wie vor 15 Jahren, fürchten viele. Bei der letzten Cholera-Epidemie 2008 starben in Simbabwe mehr als 4.000 Menschen.\nIn Kuwadzana verkaufen Straßenhändler Fisch und Fleisch, von Fliegen umschwärmt. Das will die Regierung eigentlich verbieten, um mögliche Ansteckung zu unterbinden. Etwas weiter stehen Menschen Schlange vor einem Wasserloch. Nur ein bis zwei Meter tief sind sie und offen. Das einzige Wasser, zu dem sie hier Zugang haben, wenn kein Tankwagen vorbeikommt.\n"Wir haben nur ein Wasserloch für die ganze Nachbarschaft", sagt ein Mann. Eine Frau berichtet: "Wir stehen hier manchmal vier Stunden an, manchmal sechs Stunden."\nDie Gesundheitsbehörde von Harare geht davon aus, dass mittlerweile die Hälfte dieser flachen Wasserlöcher in den westlichen Stadtteilen mit Cholera-Bakterien verseucht sind und alle tiefen Brunnen. Doch solange es kein sauberes Wasser für alle gibt, wird Cholera ein massives Problem bleiben in Simbabwe. ...
#  'content_as_list': ['<strong>Simbabwe kämpft gegen einen Cholera-Ausbruch. Seit Februar sind bereits mehr als 200 Menschen an der hochansteckenden Durchfallerkrankung gestorben, Tausende haben sich infiziert. Experten vermuten noch höhere Zahlen.</strong>',
#   '<em>Von Karin Wehrheim, ARD Johannesburg</em>',
#   'In Kuwadzana, einem Vorort von Harare, fließt das Abwasser zwischen den Hütten hindurch. Es ist mit Cholera-Bakterien verseuchtes Wasser aus aufgeplatzten Abwasserrohren. Berge von Müll türmen sich an den Straßen. Das gehe schon seit Monaten so, sagt Lucia Rupende und zeigt auf Maden in den Pfützen. Ihre Kinder lässt sie deshalb nicht hinaus.',
#   '"Das ist schrecklich. Sind wir Tiere?", fragt sie. "Es ist unerträglich, wie wir leben." Die Kinder müssten drinnen bleiben und könnten nicht draußen spielen. "Wir haben Angst, dass sie sich mit Cholera anstecken", sagt sie.',
#   '40 Prozent der Cholera-Fälle in der Hauptstadt werden derzeit aus dem Vorort Kuwadzana gemeldet. Dort leben Menschen mit wenig Geld. Stephen Masvingo hält sich mit einem Barbershop über Wasser. Sein Salon aus Blech und Brettern hat keinen Wasseranschluss. ',
#   'Er ist froh, Cholera überlebt zu haben. Drei Tage habe er Durchfall gehabt, musste sich übergeben, erzählt er. "Ich dachte, das vergeht. Aber ich konnte nichts bei mir behalten." Er habe sich sehr schwach gefühlt. "Dann hat meine Frau Hilfe geholt, ich kam sofort ins Krankenhaus."',
#   'Stephen Masvingo geht davon aus, dass er sich bei einem Kunden angesteckt hat. Manchmal vergesse man einfach, sich die Hände zu waschen - und esse<strong> </strong>dann was oder kaue Nägel.',
#   'In Simbabwe wie auch in den Nachbarländern Mosambik und Südafrika gibt es immer wieder Cholera-Epidemien, weil die Wasser- und Abwasserleitungen marode sind. Regina Feindt arbeitet für die Welthungerhilfe in Harare. Sie berichtet, nicht jeder Haushalt habe eine eigene Toilette. "Und Gemeinschaftstoiletten sind in einem teils schlechten Zustand. Das heißt, die Menschen gehen auch teilweise einfach hinters Haus."',
#   'Der nächste Regen nimmt es mit. So gelangt das stinkende Abwasser, das Lucias Rupendes Hütte umgibt, über einen Bach schließlich in den Chivero-Stausee, Harares wichtigsten Trinkwasserspeicher. ',
#   'Die Durchfallkrankheit finde im südlichen Afrika besonders leicht Opfer. In Simbabwe sei die Ernährungssituation ohnehin sehr angespannt, ungefähr 30 Prozent der Bevölkerung seien schlecht ernährt. In solchen Ländern sei "eine solche Erkrankung ein Riesenproblem, die den Hunger letztendlich noch einmal verschärft".',
#   'Bisher geht die Regierung von 9.400 Cholera-Fällen in Simbabwe aus. Doch das ist vermutlich nur die Spitze des Eisbergs. Viele gehen nicht zum Arzt, manche haben auch keine Symptome, geben die Krankheit aber trotzdem weiter.',
#   'Schon Mitte November hatte der Chef der städtischen Gesundheitsbehörde erklärt, die Lage in Harare gerate außer Kontrolle. Regierung und Hilfsorganisationen verteilten Chlortabletten, Seife und sauberes Wasser aus Tankwagen. Aber wenn jetzt die Regenzeit beginnt, könnte die Lage so schlimm werden wie vor 15 Jahren, fürchten viele. Bei der letzten Cholera-Epidemie 2008 starben in Simbabwe mehr als 4.000 Menschen.',
#   'In Kuwadzana verkaufen Straßenhändler Fisch und Fleisch, von Fliegen umschwärmt. Das will die Regierung eigentlich verbieten, um mögliche Ansteckung zu unterbinden. Etwas weiter stehen Menschen Schlange vor einem Wasserloch. Nur ein bis zwei Meter tief sind sie und offen. Das einzige Wasser, zu dem sie hier Zugang haben, wenn kein Tankwagen vorbeikommt.',
#   '"Wir haben nur ein Wasserloch für die ganze Nachbarschaft", sagt ein Mann. Eine Frau berichtet: "Wir stehen hier manchmal vier Stunden an, manchmal sechs Stunden."',
#   'Die Gesundheitsbehörde von Harare geht davon aus, dass mittlerweile die Hälfte dieser flachen Wasserlöcher in den westlichen Stadtteilen mit Cholera-Bakterien verseucht sind und alle tiefen Brunnen. Doch solange es kein sauberes Wasser für alle gibt, wird Cholera ein massives Problem bleiben in Simbabwe. ',
#   'Sheila Chimanya versucht als Gesundheitsbeauftragte in Kuwadzana, allen klarzumachen, wie sie sich schützen können: mit Hygiene und Chlortabletten für jedes Wasser. "Aber es ist schwer, die Menschen hier wissen nicht mehr, was sie tun sollen."',
#   '<strong>Über dieses Thema berichtete Deutschlandfunk am 29. November 2023 um 13:25 Uhr.</strong>'],
#  'tags': ['Simbabwe', 'Cholera', 'Krankheiten'],
#  'ressort': 'ausland',
#  'type': 'story',
#  'tag_0': 'Simbabwe',
#  'tag_1': 'Cholera',
#  'tag_2': 'Krankheiten'}

# %% [markdown]
# ## Parsing all articles

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
# creates empty dataframe  
all_files = os.listdir('data/')
df = pd.DataFrame(columns=['index','title','content','content_as_list','ressort','type','tag_0','tag_1','tag_2','tag_3','tag_4','tags','path'])
df.set_index('index',inplace= True)
df
# Out:
# Empty DataFrame
# Columns: [title, content, content_as_list, ressort, type, tag_0, tag_1, tag_2, tag_3, tag_4, tags, path]
# Index: []

# %%
## Parses all articles in the data folder
for path in all_files:
    df.loc[len(df)] = tagesschau_article('data/'+path).to_dict()
    df.at[len(df)-1,'path']= path
df
# Out:
# /tmp/ipykernel_9424/1498719563.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '-inland-innenpolitik-ermittlungen-hackerangriff-bundesamt-kartographie-100.json' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df.at[len(df)-1,'path']= path
#                                                    title  \
# index
# 0      Berlin macht Peking für Cyberangriff verantwor...
# 1      SPD plädiert für Wahl Reichinneks in Kontrollg...
# 2                Proteste gegen rechtsliberale Regierung
# 3       Israel meldet Kontrolle über Korridor zu Ägypten
# 4                  Kubicki ruft zu Kampfbereitschaft auf
# ...                                                  ...
# 14929                       ÖPNV - on demand und autonom
# 14930             Tod nach Narkose - Wenn Ärzte pfuschen
# 14931     Wie weit reicht das Recht auf Vergessenwerden?
# 14932  Tschechischer Schriftsteller Ivan Klima gestorben
# 14933               Allergien - fast das ganze Jahr lang
#
#                                                  content  \
# index
# 0      <strong>Lange wurde es vermutet, nun ist sich ...
# 1      <strong>Der Bundestag wählt heute die Mitglied...
# 2      <strong>In Argentinien haben Hunderttausende i...
# 3      <strong>Israel hat nach eigenen Angaben im Gaz...
# 4      <strong>Beim außerordentlichen FDP-Parteitag i...
# ...                                                  ...
# 14929  <strong>Lange Wege zum Supermarkt und Geldauto...
# 14930  <strong>In den vergangenen zehn Jahren sind 21...
# 14931  <strong>Muss Google verhindern, dass illegal v...
# 14932  <strong>Der Schriftsteller Ivan Klima überlebt...
# 14933  <strong>Fast das ganze Jahr über juckende oder...
#
#                                          content_as_list       ressort   type  \
# index
# 0      [<strong>Lange wurde es vermutet, nun ist sich...        inland  story
# 1      [<strong>Der Bundestag wählt heute die Mitglie...        inland  story
# 2      [<strong>In Argentinien haben Hunderttausende ...       ausland  story
# 3      [<strong>Israel hat nach eigenen Angaben im Ga...       ausland  story
# 4      [<strong>Beim außerordentlichen FDP-Parteitag ...        inland  story
# ...                                                  ...           ...    ...
# 14929  [<strong>Lange Wege zum Supermarkt und Geldaut...    wirtschaft  story
# 14930  [<strong>In den vergangenen zehn Jahren sind 2...  investigativ  story
# 14931  [<strong>Muss Google verhindern, dass illegal ...  investigativ  story
# 14932  [<strong>Der Schriftsteller Ivan Klima überleb...       ausland  story
# 14933  [<strong>Fast das ganze Jahr über juckende ode...        wissen  story
#
#                        tag_0             tag_1                       tag_2  \
# index
# 0              Hackerangriff             China  Bundesamt für Kartographie
# 1      Geheimdienstkontrolle     Linksfraktion                   Bundestag
# 2                Argentinien           Protest                       Milei
# 3               Gazastreifen            Israel                      Nahost
# 4        Bundestagswahl 2025               FDP                         NaN
# ...                      ...               ...                         ...
# 14929                   ÖPNV  Autonomes Fahren               Deutsche Bahn
# 14930             Arztpraxen           Narkose                         Tod
# 14931   Sexualisierte Gewalt     Internetsuche                       Klage
# 14932             Ivan Klima    Schriftsteller                         Tod
# 14933              Allergien       Klimawandel                       COP29
#
#         tag_3                              tag_4  \
# index
# 0         NaN                                NaN
# 1        PKGr  Parlamentarisches Kontrollgremium
# 2       LGBTQ                                NaN
# 3         NaN                                NaN
# 4         NaN                                NaN
# ...       ...                                ...
# 14929     NaN                                NaN
# 14930     NaN                                NaN
# 14931  Google                                NaN
# 14932     NaN                                NaN
# 14933     NaN                                NaN
#
#                                                     tags  \
# index
# 0      [Hackerangriff, China, Bundesamt für Kartograp...
# 1      [Geheimdienstkontrolle, Linksfraktion, Bundest...
# 2                   [Argentinien, Protest, Milei, LGBTQ]
# 3                         [Gazastreifen, Israel, Nahost]
# 4                             [Bundestagswahl 2025, FDP]
# ...                                                  ...
# 14929            [ÖPNV, Autonomes Fahren, Deutsche Bahn]
# 14930                         [Arztpraxen, Narkose, Tod]
# 14931  [Sexualisierte Gewalt, Internetsuche, Klage, G...
# 14932                  [Ivan Klima, Schriftsteller, Tod]
# 14933                    [Allergien, Klimawandel, COP29]
#
#                                                     path
# index
# 0      -inland-innenpolitik-ermittlungen-hackerangrif...
# 1      -inland-innenpolitik-geheimdienstkontrolle-rei...
# 2      -ausland-amerika-argentinien-proteste-milei-10...
# 3            -ausland-asien-gazastreifen-israel-110.json
# 4      -inland-bundestagswahl-fdp-sonderparteitag-100...
# ...                                                  ...
# 14929  -wirtschaft-verbraucher-bahn-kira-verkehr-100....
# 14930  -investigativ-report-mainz-arztpraxen-narkose-...
# 14931  -investigativ-swr-internet-suchanfragen-privat...
# 14932            -ausland-europa-ivan-klima-tod-100.json
# 14933  -wissen-klima-klimakonferenz-klima-allergien-u...
#
# [14934 rows x 12 columns]

# %%
## the different ressorts
df['ressort'].value_counts()
# Out:
# ressort
# ausland         6073
# inland          3359
# wirtschaft      3099
# wissen           801
# investigativ     292
# faktenfinder     133
# sport             15
# Name: count, dtype: int64

# %%
## number of tags per article
num_tags =  [len(i) for i in df['tags']]
plt.hist(num_tags)
plt.title('number of tags per aticle')
plt.xlabel('num of tags')
plt.ylabel('count of articles')
# Out:
# Text(0, 0.5, 'count of articles')

# %%
## length of content per article
len_content =  [len(i) for i in df['content']]
plt.hist(len_content)
plt.title('length of content')
plt.xlabel('length of content')
plt.ylabel('count of articles')
# Out:
# Text(0, 0.5, 'count of articles')

# %%
## length of contetn per articel
len_title =  [len(i) for i in df['title']]
plt.hist(len_title)
plt.title('length of titel')
plt.xlabel('length of title')
plt.ylabel('count of articles')
# Out:
# Text(0, 0.5, 'count of articles')

# %%
tag_columns = ['tag_0','tag_1','tag_2','tag_3','tag_4']
all_tags = []
for column in tag_columns:
    all_tags = all_tags + df[column].to_list()

# %%
## most used tags
all_tags = pd.Series(all_tags)
all_tags.value_counts()[:10].plot.bar()
plt.title('10 moste used tags')
# Out:
# Text(0.5, 1.0, '10 moste used tags')

# %%
## number of articles with same tags
df['tags'].value_counts()[:15].plot.bar()
plt.title('articel with exact same tags')
# Out:
# Text(0.5, 1.0, 'articel with exact same tags')

# %% [markdown]
# ## Filter articles

# %%
filterd_df = df.copy()
filterd_df
# Out:
#                                                    title  \
# index
# 0      Berlin macht Peking für Cyberangriff verantwor...
# 1      SPD plädiert für Wahl Reichinneks in Kontrollg...
# 2                Proteste gegen rechtsliberale Regierung
# 3       Israel meldet Kontrolle über Korridor zu Ägypten
# 4                  Kubicki ruft zu Kampfbereitschaft auf
# ...                                                  ...
# 14929                       ÖPNV - on demand und autonom
# 14930             Tod nach Narkose - Wenn Ärzte pfuschen
# 14931     Wie weit reicht das Recht auf Vergessenwerden?
# 14932  Tschechischer Schriftsteller Ivan Klima gestorben
# 14933               Allergien - fast das ganze Jahr lang
#
#                                                  content  \
# index
# 0      <strong>Lange wurde es vermutet, nun ist sich ...
# 1      <strong>Der Bundestag wählt heute die Mitglied...
# 2      <strong>In Argentinien haben Hunderttausende i...
# 3      <strong>Israel hat nach eigenen Angaben im Gaz...
# 4      <strong>Beim außerordentlichen FDP-Parteitag i...
# ...                                                  ...
# 14929  <strong>Lange Wege zum Supermarkt und Geldauto...
# 14930  <strong>In den vergangenen zehn Jahren sind 21...
# 14931  <strong>Muss Google verhindern, dass illegal v...
# 14932  <strong>Der Schriftsteller Ivan Klima überlebt...
# 14933  <strong>Fast das ganze Jahr über juckende oder...
#
#                                          content_as_list       ressort   type  \
# index
# 0      [<strong>Lange wurde es vermutet, nun ist sich...        inland  story
# 1      [<strong>Der Bundestag wählt heute die Mitglie...        inland  story
# 2      [<strong>In Argentinien haben Hunderttausende ...       ausland  story
# 3      [<strong>Israel hat nach eigenen Angaben im Ga...       ausland  story
# 4      [<strong>Beim außerordentlichen FDP-Parteitag ...        inland  story
# ...                                                  ...           ...    ...
# 14929  [<strong>Lange Wege zum Supermarkt und Geldaut...    wirtschaft  story
# 14930  [<strong>In den vergangenen zehn Jahren sind 2...  investigativ  story
# 14931  [<strong>Muss Google verhindern, dass illegal ...  investigativ  story
# 14932  [<strong>Der Schriftsteller Ivan Klima überleb...       ausland  story
# 14933  [<strong>Fast das ganze Jahr über juckende ode...        wissen  story
#
#                        tag_0             tag_1                       tag_2  \
# index
# 0              Hackerangriff             China  Bundesamt für Kartographie
# 1      Geheimdienstkontrolle     Linksfraktion                   Bundestag
# 2                Argentinien           Protest                       Milei
# 3               Gazastreifen            Israel                      Nahost
# 4        Bundestagswahl 2025               FDP                         NaN
# ...                      ...               ...                         ...
# 14929                   ÖPNV  Autonomes Fahren               Deutsche Bahn
# 14930             Arztpraxen           Narkose                         Tod
# 14931   Sexualisierte Gewalt     Internetsuche                       Klage
# 14932             Ivan Klima    Schriftsteller                         Tod
# 14933              Allergien       Klimawandel                       COP29
#
#         tag_3                              tag_4  \
# index
# 0         NaN                                NaN
# 1        PKGr  Parlamentarisches Kontrollgremium
# 2       LGBTQ                                NaN
# 3         NaN                                NaN
# 4         NaN                                NaN
# ...       ...                                ...
# 14929     NaN                                NaN
# 14930     NaN                                NaN
# 14931  Google                                NaN
# 14932     NaN                                NaN
# 14933     NaN                                NaN
#
#                                                     tags  \
# index
# 0      [Hackerangriff, China, Bundesamt für Kartograp...
# 1      [Geheimdienstkontrolle, Linksfraktion, Bundest...
# 2                   [Argentinien, Protest, Milei, LGBTQ]
# 3                         [Gazastreifen, Israel, Nahost]
# 4                             [Bundestagswahl 2025, FDP]
# ...                                                  ...
# 14929            [ÖPNV, Autonomes Fahren, Deutsche Bahn]
# 14930                         [Arztpraxen, Narkose, Tod]
# 14931  [Sexualisierte Gewalt, Internetsuche, Klage, G...
# 14932                  [Ivan Klima, Schriftsteller, Tod]
# 14933                    [Allergien, Klimawandel, COP29]
#
#                                                     path
# index
# 0      -inland-innenpolitik-ermittlungen-hackerangrif...
# 1      -inland-innenpolitik-geheimdienstkontrolle-rei...
# 2      -ausland-amerika-argentinien-proteste-milei-10...
# 3            -ausland-asien-gazastreifen-israel-110.json
# 4      -inland-bundestagswahl-fdp-sonderparteitag-100...
# ...                                                  ...
# 14929  -wirtschaft-verbraucher-bahn-kira-verkehr-100....
# 14930  -investigativ-report-mainz-arztpraxen-narkose-...
# 14931  -investigativ-swr-internet-suchanfragen-privat...
# 14932            -ausland-europa-ivan-klima-tod-100.json
# 14933  -wissen-klima-klimakonferenz-klima-allergien-u...
#
# [14934 rows x 12 columns]

# %%
## remove too long and short articles

filterd_df = filterd_df[[True if len(i) <15_000 else False for i in filterd_df['content']]]
filterd_df = filterd_df[[True if len(i) >1000 else False for i in filterd_df['content']]]

# %%
## remove tags
## remove all Liveblog
tags_to_remove = ['Liveblog','Kommentar','FAQ']
for tag in tags_to_remove:
    filterd_df = filterd_df[[True if tag not in i else False for i in filterd_df['tags']]]

# %%
tag_columns = ['tag_0','tag_1','tag_2','tag_3','tag_4']
all_tags = []
for column in tag_columns:
    all_tags = all_tags + filterd_df[column].to_list()
all_tags = pd.Series(all_tags)
top_k_tags = all_tags.value_counts()[:50].index
top_k_tags
# Out:
# Index(['USA', 'Trump', 'Ukraine', 'Israel', 'Russland', 'Nahost', 'EU',
#        'Eilmeldung', 'Bundestagswahl 2025', 'China', 'Zölle', 'Merz', 'Iran',
#        'AfD', 'SPD', 'Marktbericht', 'Syrien', 'Frankreich', 'Gaza', 'DAX',
#        'Klimawandel', 'Hamas', 'Migration', 'Börse', 'Bundestag',
#        'Gazastreifen', 'Türkei', 'Union', 'Bundesregierung',
#        'Regierungsbildung', 'Deutschland', 'Putin', 'Elon Musk',
#        'Großbritannien', 'NATO', 'Selenskyj', 'Bundeswehr', 'Inflation', 'CDU',
#        'Afghanistan', 'Konjunktur', 'Polen', 'Olaf Scholz', 'KI', 'Indien',
#        'Interview', 'Deutsche Bahn', 'Waffenruhe', 'Österreich', 'Italien'],
#       dtype='object')

# %%
## has to have 2 tags
filterd_df = filterd_df[[True if len(i) >=2 else False for i in filterd_df['tags']]]

# %%
## has to be in top k tags

filterd_df = filterd_df[[True if len(set(tags).intersection(top_k_tags)) >= 1 else False for tags in filterd_df['tags']]]

# %%
filterd_df
# Out:
#                                                    title  \
# index
# 0      Berlin macht Peking für Cyberangriff verantwor...
# 1      SPD plädiert für Wahl Reichinneks in Kontrollg...
# 3       Israel meldet Kontrolle über Korridor zu Ägypten
# 4                  Kubicki ruft zu Kampfbereitschaft auf
# 5                           US-Anleger meiden das Risiko
# ...                                                  ...
# 14924             Trump droht Nigeria mit Militäreinsatz
# 14925  Noch kein Beschluss über E-Auto-Pflicht in der EU
# 14927     Was wird aus dem Ziel der Kreislaufwirtschaft?
# 14929                       ÖPNV - on demand und autonom
# 14933               Allergien - fast das ganze Jahr lang
#
#                                                  content  \
# index
# 0      <strong>Lange wurde es vermutet, nun ist sich ...
# 1      <strong>Der Bundestag wählt heute die Mitglied...
# 3      <strong>Israel hat nach eigenen Angaben im Gaz...
# 4      <strong>Beim außerordentlichen FDP-Parteitag i...
# 5      <strong>Trotz eines knappen neuen Dow-Rekords ...
# ...                                                  ...
# 14924  <strong>US-Präsident Trump hat Nigerias Regier...
# 14925  <strong>Die EU-Kommission plant einem Medienbe...
# 14927  <strong>Wiederverwenden statt wegwerfen und da...
# 14929  <strong>Lange Wege zum Supermarkt und Geldauto...
# 14933  <strong>Fast das ganze Jahr über juckende oder...
#
#                                          content_as_list     ressort   type  \
# index
# 0      [<strong>Lange wurde es vermutet, nun ist sich...      inland  story
# 1      [<strong>Der Bundestag wählt heute die Mitglie...      inland  story
# 3      [<strong>Israel hat nach eigenen Angaben im Ga...     ausland  story
# 4      [<strong>Beim außerordentlichen FDP-Parteitag ...      inland  story
# 5      [<strong>Trotz eines knappen neuen Dow-Rekords...  wirtschaft  story
# ...                                                  ...         ...    ...
# 14924  [<strong>US-Präsident Trump hat Nigerias Regie...     ausland  story
# 14925  [<strong>Die EU-Kommission plant einem Medienb...  wirtschaft  story
# 14927  [<strong>Wiederverwenden statt wegwerfen und d...      inland  story
# 14929  [<strong>Lange Wege zum Supermarkt und Geldaut...  wirtschaft  story
# 14933  [<strong>Fast das ganze Jahr über juckende ode...      wissen  story
#
#                        tag_0             tag_1                       tag_2  \
# index
# 0              Hackerangriff             China  Bundesamt für Kartographie
# 1      Geheimdienstkontrolle     Linksfraktion                   Bundestag
# 3               Gazastreifen            Israel                      Nahost
# 4        Bundestagswahl 2025               FDP                         NaN
# 5               Marktbericht          Finanzen                      Aktien
# ...                      ...               ...                         ...
# 14924                  Trump           Nigeria                    Christen
# 14925       Verbrennerverbot                EU                     E-Autos
# 14927    Kreislaufwirtschaft             Union                         SPD
# 14929                   ÖPNV  Autonomes Fahren               Deutsche Bahn
# 14933              Allergien       Klimawandel                       COP29
#
#               tag_3                              tag_4  \
# index
# 0               NaN                                NaN
# 1              PKGr  Parlamentarisches Kontrollgremium
# 3               NaN                                NaN
# 4               NaN                                NaN
# 5      Jackson Hole                                DAX
# ...             ...                                ...
# 14924           NaN                                NaN
# 14925   Dienstwagen                                NaN
# 14927           NaN                                NaN
# 14929           NaN                                NaN
# 14933           NaN                                NaN
#
#                                                     tags  \
# index
# 0      [Hackerangriff, China, Bundesamt für Kartograp...
# 1      [Geheimdienstkontrolle, Linksfraktion, Bundest...
# 3                         [Gazastreifen, Israel, Nahost]
# 4                             [Bundestagswahl 2025, FDP]
# 5      [Marktbericht, Finanzen, Aktien, Jackson Hole,...
# ...                                                  ...
# 14924                         [Trump, Nigeria, Christen]
# 14925       [Verbrennerverbot, EU, E-Autos, Dienstwagen]
# 14927                  [Kreislaufwirtschaft, Union, SPD]
# 14929            [ÖPNV, Autonomes Fahren, Deutsche Bahn]
# 14933                    [Allergien, Klimawandel, COP29]
#
#                                                     path
# index
# 0      -inland-innenpolitik-ermittlungen-hackerangrif...
# 1      -inland-innenpolitik-geheimdienstkontrolle-rei...
# 3            -ausland-asien-gazastreifen-israel-110.json
# 4      -inland-bundestagswahl-fdp-sonderparteitag-100...
# 5      -wirtschaft-finanzen-marktberichte-marktberich...
# ...                                                  ...
# 14924    -ausland-amerika-trump-nigeria-drohung-100.json
# 14925  -wirtschaft-technologie-eu-verbrennerverbot-di...
# 14927  -inland-innenpolitik-kreislaufwirtschaft-geset...
# 14929  -wirtschaft-verbraucher-bahn-kira-verkehr-100....
# 14933  -wissen-klima-klimakonferenz-klima-allergien-u...
#
# [7191 rows x 12 columns]

# %%
filterd_df.to_csv('tagesschau_filterd_articles.csv',index=False)
